# %%
# !pip install gpt-2-simple
# Out:
# Requirement already satisfied: gpt-2-simple in /anaconda3/envs/learn-env/lib/python3.7/site-packages (0.5.1)
# Requirement already satisfied: requests in /anaconda3/envs/learn-env/lib/python3.7/site-packages (from gpt-2-simple) (2.21.0)
# Requirement already satisfied: tqdm in /anaconda3/envs/learn-env/lib/python3.7/site-packages (from gpt-2-simple) (4.31.1)
# Requirement already satisfied: numpy in /anaconda3/envs/learn-env/lib/python3.7/site-packages (from gpt-2-simple) (1.16.4)
# Requirement already satisfied: toposort in /anaconda3/envs/learn-env/lib/python3.7/site-packages (from gpt-2-simple) (1.5)
# Requirement already satisfied: regex in /anaconda3/envs/learn-env/lib/python3.7/site-packages (from gpt-2-simple) (2019.6.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /anaconda3/envs/learn-env/lib/python3.7/site-packages (from requests->gpt-2-simple) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/envs/learn-env/lib/python3.7/site-packages (from requests->gpt-2-simple) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/envs/learn-env/lib/python3.7/site-packages (from requests->gpt-2-simple) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/envs/learn-env/lib/python3.7/site-packages (from requests->gpt-2-simple) (2.8)

# %%
import tensorflow as tf
import gpt_2_simple as gpt2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-6a2a867fa693> in <module>()
#       1 import tensorflow as tf
# ----> 2 import gpt_2_simple as gpt2
#
# /anaconda3/envs/learn-env/lib/python3.7/site-packages/gpt_2_simple/__init__.py in <module>()
# ----> 1 from .gpt_2 import *
#
# /anaconda3/envs/learn-env/lib/python3.7/site-packages/gpt_2_simple/gpt_2.py in <module>()
#      21     pass
#      22
# ---> 23 from gpt_2_simple.src import model, sample, encoder, memory_saving_gradients
#      24 from gpt_2_simple.src.load_dataset import load_dataset, Sampler
#      25 from gpt_2_simple.src.accumulate import AccumulatingOptimizer
#
# /anaconda3/envs/learn-env/lib/python3.7/site-packages/gpt_2_simple/src/model.py in <module>()
#       1 import numpy as np
#       2 import tensorflow as tf
# ----> 3 from tensorflow.contrib.training import HParams
#       4
#       5 def default_hparams():
#
# ModuleNotFoundError: No module named 'tensorflow.contrib'

# %%
model_name = "117M"
gpt2.download_gpt2(model_name=model_name)   # model is saved into current directory under /models/117M/
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-888d81f4b1fd> in <module>()
# ----> 1 import gpt_2_simple as gpt2
#       2
#       3 model_name = "117M"
#       4 gpt2.download_gpt2(model_name=model_name)   # model is saved into current directory under /models/117M/
#
# /anaconda3/envs/learn-env/lib/python3.7/site-packages/gpt_2_simple/__init__.py in <module>()
# ----> 1 from .gpt_2 import *
#
# /anaconda3/envs/learn-env/lib/python3.7/site-packages/gpt_2_simple/gpt_2.py in <module>()
#      21     pass
#      22
# ---> 23 from gpt_2_simple.src import model, sample, encoder, memory_saving_gradients
#      24 from gpt_2_simple.src.load_dataset import load_dataset, Sampler
#      25 from gpt_2_simple.src.accumulate import AccumulatingOptimizer
#
# /anaconda3/envs/learn-env/lib/python3.7/site-packages/gpt_2_simple/src/model.py in <module>()
#       1 import numpy as np
#       2 import tensorflow as tf
# ----> 3 from tensorflow.contrib.training import HParams
#       4
#       5 def default_hparams():
#
# ModuleNotFoundError: No module named 'tensorflow.contrib'

# %%
import json
with open('artists/eminem.json') as f:
    raps = json.load(f)

# %%
rap_titles = list(raps.keys())

# %%
corpus = ""

for song, lyrics in raps.items():
    corpus +=  ' \n\n\n ' + song + ' \n\n '
    corpus += lyrics.replace('\n', ' \n')

# %%
# file = open("corpus.txt","w") 
 
# file.write(corpus)  
# file.close()

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              "corpus.txt",
              model_name=model_name,
              learning_rate=0.01,
              steps=5)   # steps is max number of training steps

gpt2.generate(sess)
# Out:
# Loading checkpoint checkpoint/run1/model-8
# INFO:tensorflow:Restoring parameters from checkpoint/run1/model-8
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:03<00:00,  3.78s/it]
# dataset has 516974 tokens
# Training...
# [9 | 204.12] loss=3.15 avg=3.15
# [10 | 405.60] loss=21.13 avg=12.18
# [11 | 607.87] loss=9.35 avg=11.23
# [12 | 837.05] loss=13.29 avg=11.75
# [13 | 1074.92] loss=12.30 avg=11.86
# Saving checkpoint/run1/model-13
#  you
# '
#  in
#
#
#
#
#  you's
# 's
# ' only
#
#
# 's
#
#
#
#
#
#
#
#
# ' you's
#
#
#
# '
#  you you to
#
#
#
#
#  that
#
#
#
# :
# 's
# 'There the
#
# '
#  '
#
#
#
#  it
#
#
#
#
#
#
#
#
#
#
#
# '
#
#
#  up
#
#
#
#  in
#
#
#
#
#  and
#  have
#
#
#
#
#
#  to
#
#
#
#
#  a and-
# 's
#  to
#
#  your
#
#  the's
#  you
#
#
#
#
#
#  a '
#
#
# '
#
# '
# '
#
#
#
#
#
#
#
#
#
#
#  you
#
#
#  you
#
#  Sh
#
#
#
#
#
#
#
# '' you
#  to
# 's do
#
#
#  is
#  and
# I
#
#
# 's been
#  in
#
#
#
#  back
#
#
#
#
# ' you'
# 's
#
#
#
#
#
#
#
# '
# '
# ''s
#  you's
#
#
#
#  theI you
#
#  all?
#
# 's
#
#  you a
#
# '
#
#
#
#  to
#
#
#
#
#
# '
#
#
#  one
#  my
# I
#
#
#
# '
#
#
#
#
#
#
#  to
#
# ''s'
#
#
# ' back
#  you
#
#
#
#
#
#
#
# ''
#
#
#
#
#  you'
#
#
#
#
# 's
#
#
#
# 's
#  you
# ' you
#
#
#
#
#  in
#
# 's
#
#
#
#
#
#
# '
#
#
#
# ' you
#
#
#
#
#
#
#  you
#
#
#
#
#
#
# '
#
#
#
#
#
#
#
#  in
#
#
#
# ''s you to
#
#
# '
#
#
#
#
#
#
#  you
#
#
#  never's you's
#  have'
#
#
# No
# 's
#  just
#
#
#
# '
#
#  a
#  no to
#
#
#
#
#  you
#
#
#
#
#
#
#  to
# 's
# '
#
#
#  you
#  [
#
#
#
#
# '
#
# ' you
#
#
#
#  youI time's you
# ' in a
#
#
#  in
# :
#
#
#
#
#  you you
#
#
# 's you
#
#  you
#
#
#
# 's
#
#
# 's
#
#
#
#
# 's
#
#
#  not
#
#  mother'' in
#
#
#
#  you
#
#
#
#
#
#
#
#
#
#
#
#  you on'
#
#
#
# ' to
#
#
#
# 's
# ' you you let to' of
# 'sI
# '
#
#
#
#
#
# 's that
#  you to
#
#  a
#  in's don you
# 's you
#
#
#
#  to's to'
#
#
#
#
#  myI
# 's don
# '
# '
#
#
#
#
#
#
# 's to
#  like
#  you
#  the's
#
#
#
# 's'
#
#  it
# "
#
#
#
#
# '
# I
#  on
#  you
#
#
#
# '
#
# '
#  it
#
#
# '
#
#
#
# I's
# 's- you
#
# '
#  you you
#  my back
# 'sI to
#  and you
# 's
#
# I the you you
#
#
#
#  to
#
#  a
# '
#
#
#
#  just
#
#
#
#
#
#
#  your
#
#
#
#
#
#
#  your
#
# ''
#
#  in
#
# '
#
# '
# 's to you
#  you
#
#
#
#  my
#
#
#  you
#
#
#
#
#
#  the
#
# 's
#  to
#
# 's
#
#
#
#
#
#  in' to
# ' on just
#
#  you
#
#
#
#
#
#
# ''
#  you
#
#
#
# '
# ' have's don's you
# 's to
#
#
#  a
#
#
#
#
#
#
# 's
#
#
# '
#
#
#  with
#
#
#
# '
#
#
#  your
# 's
#
# ' onI's a to
#
#  can
#
#  out
#
# ''
#  you
#
#
#
#
#
# -
# 's
#
#
#
#
#
#
#  and
#  been
#  with'
#  making ' do' back'
#
#  in with's you
#
#
#
#
#
#
#
# 's
#
#
# 's
#
# 's
# 's' back'
#
#  you
#  and
#
#
#  '
#
#
# 's you and
#
#
# I's
#  a
#
#  you
#
#
#
#
# ' do
#
#
# '
#  and the
#
#
#
#  with
#
#  a'
#  you and'
#
#  back you you you a
#  to
#
#
#
#
#  to
#
#
#  out to
# ' that
#  you
#
#  to
#
#
#
#
#
#
#
#
#
#
#
#  everything
# It
#
#
#  don you out
# '
